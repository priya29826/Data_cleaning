# %% [markdown]
# **Pandas day 1**

# %%
#Movie dataset
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/master/Movie-Dataset-Latest.csv")

# %%
data
# Out:
#       Unnamed: 0      id                        title release_date  \
# 0              0   19404  Dilwale Dulhania Le Jayenge   1995-10-20
# 1              1     278     The Shawshank Redemption   1994-09-23
# 2              2     238                The Godfather   1972-03-14
# 3              3  724089    Gabriel's Inferno Part II   2020-07-31
# 4              4     424             Schindler's List   1993-11-30
# ...          ...     ...                          ...          ...
# 9458        9458   13805               Disaster Movie   2008-08-29
# 9459        9459    5491            Battlefield Earth   2000-05-12
# 9460        9460   11059            House of the Dead   2003-04-11
# 9461        9461   14164         Dragonball Evolution   2009-03-12
# 9462        9462   40016   Birdemic: Shock and Terror   2010-02-27
#
#                                                overview  popularity  \
# 0     Raj is a rich, carefree, happy-go-lucky second...      25.884
# ...

# %%
#display top of the dataset
data.head()
# Out:
#    Unnamed: 0      id                        title release_date  \
# 0           0   19404  Dilwale Dulhania Le Jayenge   1995-10-20
# 1           1     278     The Shawshank Redemption   1994-09-23
# 2           2     238                The Godfather   1972-03-14
# 3           3  724089    Gabriel's Inferno Part II   2020-07-31
# 4           4     424             Schindler's List   1993-11-30
#
#                                             overview  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...      25.884
# 1  Framed in the 1940s for the double murder of h...      60.110
# 2  Spanning the years 1945 to 1955, a chronicle o...      62.784
# 3  Professor Gabriel Emerson finally learns the t...      28.316
# 4  The true story of how businessman Oskar Schind...      38.661
#
#    vote_average  vote_count  video
# 0           8.7        3304  False
# 1           8.7       20369  False
# 2           8.7       15219  False
# 3           8.6        1360  False
# ...

# %%
#display bottom of the dataset
data.tail()
# Out:
#       Unnamed: 0     id                       title release_date  \
# 9458        9458  13805              Disaster Movie   2008-08-29
# 9459        9459   5491           Battlefield Earth   2000-05-12
# 9460        9460  11059           House of the Dead   2003-04-11
# 9461        9461  14164        Dragonball Evolution   2009-03-12
# 9462        9462  40016  Birdemic: Shock and Terror   2010-02-27
#
#                                                overview  popularity  \
# 9458  The filmmaking team behind the hits "Scary Mov...      12.121
# 9459  In the year 3000, man is no match for the Psyc...      10.200
# 9460  Set on an island off the coast, a techno rave ...       8.120
# 9461  The young warrior Son Goku sets out on a quest...      52.129
# 9462  A platoon of eagles and vultures attacks the r...       7.341
#
#       vote_average  vote_count  video
# 9458           3.2         787  False
# 9459           3.2         628  False
# 9460           3.2         281  False
# ...

# %%
#datatype of the columns
data.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# title            object
# release_date     object
# overview         object
# popularity      float64
# vote_average    float64
# vote_count        int64
# video              bool
# dtype: object

# %%
#random sample of the dataset
data.sample()
# Out:
#       Unnamed: 0    id        title release_date  \
# 2766        2766  5916  The Getaway   1972-09-20
#
#                                                overview  popularity  \
# 2766  A recently released ex-convict and his loyal w...       7.071
#
#       vote_average  vote_count  video
# 2766           7.1         370  False

# %%
#shows a quick statistic summary of dataset
data.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  9463.000000    9463.000000   9463.000000   9463.000000   9463.000000
# mean   4731.000000  149335.006023     35.678181      6.596830   1515.020712
# std    2731.877132  197420.958246    233.491372      0.819408   2555.328387
# min       0.000000       5.000000      0.600000      2.200000    200.000000
# 25%    2365.500000    9951.000000      8.835000      6.100000    316.000000
# 50%    4731.000000   25846.000000     12.636000      6.600000    584.000000
# 75%    7096.500000  290548.500000     24.371000      7.200000   1434.500000
# max    9462.000000  876716.000000  14136.690000      8.700000  30535.000000

# %%
data.describe().T
# Out:
#                count           mean            std    min       25%  \
# Unnamed: 0    9463.0    4731.000000    2731.877132    0.0  2365.500
# id            9463.0  149335.006023  197420.958246    5.0  9951.000
# popularity    9463.0      35.678181     233.491372    0.6     8.835
# vote_average  9463.0       6.596830       0.819408    2.2     6.100
# vote_count    9463.0    1515.020712    2555.328387  200.0   316.000
#
#                     50%         75%        max
# Unnamed: 0     4731.000    7096.500    9462.00
# id            25846.000  290548.500  876716.00
# popularity       12.636      24.371   14136.69
# vote_average      6.600       7.200       8.70
# vote_count      584.000    1434.500   30535.00

# %%
#checking null values in the dataset
data.isnull()
# Out:
#       Unnamed: 0     id  title  release_date  overview  popularity  \
# 0          False  False  False         False     False       False
# 1          False  False  False         False     False       False
# 2          False  False  False         False     False       False
# 3          False  False  False         False     False       False
# 4          False  False  False         False     False       False
# ...          ...    ...    ...           ...       ...         ...
# 9458       False  False  False         False     False       False
# 9459       False  False  False         False     False       False
# 9460       False  False  False         False     False       False
# 9461       False  False  False         False     False       False
# 9462       False  False  False         False     False       False
#
#       vote_average  vote_count  video
# 0            False       False  False
# 1            False       False  False
# 2            False       False  False
# ...

# %%
#display datatype of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9463 entries, 0 to 9462
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9463 non-null   int64
#  1   id            9463 non-null   int64
#  2   title         9463 non-null   object
#  3   release_date  9463 non-null   object
#  4   overview      9449 non-null   object
#  5   popularity    9463 non-null   float64
#  6   vote_average  9463 non-null   float64
#  7   vote_count    9463 non-null   int64
#  8   video         9463 non-null   bool
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 600.8+ KB

# %%
#display dataset row and column size
data.shape
# Out:
# (9463, 9)

# %%
data["popularity"].max()
# Out:
# 14136.69

# %%
data["popularity"].min()
# Out:
# 0.6

# %%
#for finding duplicate value of the dataset
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9458    False
# 9459    False
# 9460    False
# 9461    False
# 9462    False
# Length: 9463, dtype: bool

# %%
#display the indexing of the dataset
data.index
# Out:
# RangeIndex(start=0, stop=9463, step=1)

# %%
#display the column name of the dataset
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'release_date', 'overview', 'popularity',
#        'vote_average', 'vote_count', 'video'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'id',
#  'title',
#  'release_date',
#  'overview',
#  'popularity',
#  'vote_average',
#  'vote_count',
#  'video']

# %%
#sorts by an axis
data.sort_index(axis=1, ascending=False)
# Out:
#       vote_count  vote_average  video                        title  \
# 0           3304           8.7  False  Dilwale Dulhania Le Jayenge
# 1          20369           8.7  False     The Shawshank Redemption
# 2          15219           8.7  False                The Godfather
# 3           1360           8.6  False    Gabriel's Inferno Part II
# 4          12158           8.6  False             Schindler's List
# ...          ...           ...    ...                          ...
# 9458         787           3.2  False               Disaster Movie
# 9459         628           3.2  False            Battlefield Earth
# 9460         281           3.2  False            House of the Dead
# 9461        1584           2.8  False         Dragonball Evolution
# 9462         237           2.2  False   Birdemic: Shock and Terror
#
#      release_date  popularity  \
# 0      1995-10-20      25.884
# 1      1994-09-23      60.110
# 2      1972-03-14      62.784
# 3      2020-07-31      28.316
# ...

# %%
#fetching two columns
data[['title','overview']]
# Out:
#                             title  \
# 0     Dilwale Dulhania Le Jayenge
# 1        The Shawshank Redemption
# 2                   The Godfather
# 3       Gabriel's Inferno Part II
# 4                Schindler's List
# ...                           ...
# 9458               Disaster Movie
# 9459            Battlefield Earth
# 9460            House of the Dead
# 9461         Dragonball Evolution
# 9462   Birdemic: Shock and Terror
#
#                                                overview
# 0     Raj is a rich, carefree, happy-go-lucky second...
# 1     Framed in the 1940s for the double murder of h...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     Professor Gabriel Emerson finally learns the t...
# 4     The true story of how businessman Oskar Schind...
# ...                                                 ...
# 9458  The filmmaking team behind the hits "Scary Mov...
# 9459  In the year 3000, man is no match for the Psyc...
# ...

# %%
data[['title','popularity']]
# Out:
#                             title  popularity
# 0     Dilwale Dulhania Le Jayenge      25.884
# 1        The Shawshank Redemption      60.110
# 2                   The Godfather      62.784
# 3       Gabriel's Inferno Part II      28.316
# 4                Schindler's List      38.661
# ...                           ...         ...
# 9458               Disaster Movie      12.121
# 9459            Battlefield Earth      10.200
# 9460            House of the Dead       8.120
# 9461         Dragonball Evolution      52.129
# 9462   Birdemic: Shock and Terror       7.341
#
# [9463 rows x 2 columns]
